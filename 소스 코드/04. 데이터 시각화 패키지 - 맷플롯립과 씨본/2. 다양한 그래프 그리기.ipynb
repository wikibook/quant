# %%
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import rcParams

sns.set()
# %matplotlib inline

rcParams["font.family"] = "Malgun Gothic"
rcParams["axes.unicode_minus"] = False

# %% [markdown]
# ### 선 그래프

# %%
plt.plot([1,2,3], [4,1,2], label = "line1")
plt.plot([1,2,3], [5,6,0], label = "line2")
plt.legend(loc = "upper right")

# %% [markdown]
# #### 색상 설정

# %%
plt.plot([1,2,3], [4,1,2], color = "black", label = "line1")
plt.plot([1,2,3], [5,6,0], color = "red", label = "line2")
plt.legend(loc = "upper right")

# %% [markdown]
# #### 선 스타일 및 두께 설정

# %%
plt.plot([1,2,3], [4,1,2], linestyle = "dashed", linewidth = 4, label = "line1")
plt.plot([1,2,3], [5,6,0], linestyle = "dotted", linewidth = 3, label = "line2")
plt.legend(loc = "upper right")

# %% [markdown]
# #### 마커 설정

# %%
plt.plot([1,2,3], [4,1,2], marker = "s", markersize = 8, label = "line1")
plt.plot([1,2,3], [5,6,0], marker = "o", markersize = 8, label = "line2")
plt.legend(loc = "upper right")

# %% [markdown]
# ### 산점도

# %%
plt.scatter([1,2,3], [4,1,2], label = "scatter1")
plt.scatter([1,2,3], [5,6,0], label = "scatter2")
plt.legend(loc = "upper right")

# %% [markdown]
# #### 마커 설정

# %%
plt.scatter([1,2,3], [4,1,2], marker = "*", s = 80, color = "red", label = "scatter1")
plt.scatter([1,2,3], [5,6,0], marker = "o", s = 80, color = "green", label = "scatter2")
plt.legend(loc = "upper right")

# %% [markdown]
# #### 투명도 설정

# %%
import numpy as np
x = np.random.normal(0, 1, 10000)
y = np.random.normal(0, 1, 10000)

# %%
plt.scatter(x, y)

# %%
plt.scatter(x, y, alpha = 0.05)

# %% [markdown]
# ### 막대 그래프

# %%
plt.bar(range(3), [10,20,30])
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# #### 눈금 값 설정

# %%
plt.bar(range(3), [10,20,30])
plt.xticks(range(3), ["A", "B", "C"])
# Out:
# ([<matplotlib.axis.XTick at 0x250a182a1f0>,
#   <matplotlib.axis.XTick at 0x250a1b784c0>,
#   <matplotlib.axis.XTick at 0x250a188fa60>],
#  [Text(0, 0, 'A'), Text(1, 0, 'B'), Text(2, 0, 'C')])

# %% [markdown]
# #### 스타일 설정

# %%
plt.bar(range(3), [10,20,30], width = 0.5, color = "orange", linewidth = 3.5)
plt.xticks(range(3), ["A", "B", "C"])
# Out:
# ([<matplotlib.axis.XTick at 0x250a1a9cf40>,
#   <matplotlib.axis.XTick at 0x250a1a9ce50>,
#   <matplotlib.axis.XTick at 0x250a1a3aa00>],
#  [Text(0, 0, 'A'), Text(1, 0, 'B'), Text(2, 0, 'C')])

# %%
plt.bar(
    range(3), [10, 20, 30], width=0.5, color=["orange", "blue", "green"], linewidth=3.5
)
plt.xticks(range(3), ["A", "B", "C"])
# Out:
# ([<matplotlib.axis.XTick at 0x250a1bfbbb0>,
#   <matplotlib.axis.XTick at 0x250a1bfbb80>,
#   <matplotlib.axis.XTick at 0x250a1bf6730>],
#  [Text(0, 0, 'A'), Text(1, 0, 'B'), Text(2, 0, 'C')])

# %% [markdown]
# ### 박스플롯

# %%
x = np.random.normal(10, 5, 100)
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x250a1c71880>,
#   <matplotlib.lines.Line2D at 0x250a1c71be0>],
#  'caps': [<matplotlib.lines.Line2D at 0x250a1c71f40>,
#   <matplotlib.lines.Line2D at 0x250a1c7d2e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x250a1c71520>],
#  'medians': [<matplotlib.lines.Line2D at 0x250a1c7d640>],
#  'fliers': [<matplotlib.lines.Line2D at 0x250a1c7d9a0>],
#  'means': []}

# %%
x1 = np.random.normal(10, 5, 1000)
x2 = np.random.normal(10, 10, 100)
plt.boxplot([x1, x2])
plt.show()

# %% [markdown]
# #### 눈금 값 설정

# %%
x1 = np.random.normal(10, 5, 1000)
x2 = np.random.normal(10, 10, 100)
plt.boxplot([x1, x2])
plt.xticks([1, 2], ["x1", "x2"])
plt.show()

# %% [markdown]
# ### 히스토그램

# %%
x = np.random.normal(10, 2, 100)

# %%
plt.hist(x)
plt.show()

# %%
plt.hist(x, bins = 5)
plt.show()

# %%
plt.hist(x, bins = 20)
plt.show()

# %% [markdown]
# ### 히트맵

# %%
import pandas as pd
data = pd.DataFrame({"수학": [100, 80, 90], "영어": [70, 90, 80]}, 
                   index=["철수", "영희", "민수"])
display(data)
# Out:
#      수학  영어
# 철수  100  70
# 영희   80  90
# 민수   90  80

# %%
sns.heatmap(data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 눈금 값 설정

# %%
sns.heatmap(data.values)
plt.xticks([0.5, 1.5], ["수학", "영어"])
plt.yticks([0.5, 1.5, 2.5], ["철수", "영희", "민수"])
# Out:
# ([<matplotlib.axis.YTick at 0x250a1eb8b20>,
#   <matplotlib.axis.YTick at 0x250a1fb75b0>,
#   <matplotlib.axis.YTick at 0x250a2014700>],
#  [Text(0, 0.5, '철수'), Text(0, 1.5, '영희'), Text(0, 2.5, '민수')])

# %% [markdown]
# #### 데이터 표시

# %%
sns.heatmap(data, annot = True, fmt = "d")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data, annot = True, fmt = ".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 선 스타일 설정

# %%
sns.heatmap(data, annot = True, fmt = ".2f", linewidth = 1, linecolor = "black")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 컬러맵 설정

# %%
sns.heatmap(data, annot = True, fmt = ".2f", cmap = "Greys", linewidth = 1, linecolor = "black")
# Out:
# <AxesSubplot:>
